# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = 12, 6
matplotlib.rcParams['font.size'] = 18  # Probably OS Dependent

# %% [markdown]
# ## Load Merged Data

# %%
df_noemail = pd.read_json('results/records.noemail.json')
df_noemail.sample(5, random_state=42)
# Out:
#                                         key city_type        city  \
# 233             TOWN OF LYNN - CLARK COUNTY      TOWN        LYNN
# 450       TOWN OF SUPERIOR - DOUGLAS COUNTY      TOWN    SUPERIOR
# 1240        TOWN OF SHARON - PORTAGE COUNTY      TOWN      SHARON
# 1693  TOWN OF WEST BEND - WASHINGTON COUNTY      TOWN   WEST BEND
# 411       CITY OF BEAVER DAM - DODGE COUNTY      CITY  BEAVER DAM
#
#                  county            clerk   deputy_clerk  \
# 233        CLARK COUNTY     JOYE EICHTEN           None
# 450      DOUGLAS COUNTY    CAROLYN JONES           None
# 1240     PORTAGE COUNTY      LORI PRINTZ  ALICE WIERZBA
# 1693  WASHINGTON COUNTY  JULIE IHLENFELD           None
# 411        DODGE COUNTY        ZAK BLOOM  TRACEY FERRON
#
#                                   municipal_address  \
# 233     W1877 US HIGHWAY 10, GRANTON, WI 54436-8847
# 450   4917 S STATE ROAD 35, SUPERIOR, WI 54880-8301
# 1240   6704 STATE HIGHWAY 66, CUSTER, WI 54423-9641
# 1693   6355 COUNTY ROAD Z, WEST BEND, WI 53095-9201
# 411    205 S LINCOLN AVE, BEAVER DAM, WI 53916-2323
#
#                          mailing_address                          phones  \
# 233   PO BOX 104, GRANTON, WI 54436-0104                 [(715)937-1626]
# 450                                 None                 [(715)399-8385]
# 1240                                None                 [(715)592-6600]
# 1693                                None                 [(262)338-3417]
# 411                                 None  [(920)887-4600, (920)356-2546]
#
#                 fax                               url
# 233            None                              None
# 450   (715)399-0181     http://www.townofsuperior.net
# 1240  (715)592-6666                              None
# 1693  (262)338-0427     http://www.townofwestbend.com
# 411   (920)887-4662  https://www.cityofbeaverdam.com/

# %% [markdown]
# ## Load Fetched Data

# %%
from aggregate import read_municipal_address, read_mailing_address


df_mail = pd.DataFrame(read_mailing_address()).dropna(axis=0, how='all')
df_muni = pd.DataFrame(read_municipal_address()).dropna(axis=0, how='all')

df_mail['key'] = df_mail['jurisdictionName'].str.upper()
df_muni['key'] = df_muni['jurisdictionName'].str.upper()

df_muni.sample(5, random_state=42)
# Out:
#      $id                        jurisdictionID  \
# 1177  12  7864f172-ddaf-e511-80ea-0050568c2fc0
# 1115  12  f4cd0067-ddaf-e511-80ea-0050568c2fc0
# 1662  12  b335105b-ddaf-e511-80ea-0050568c2fc0
# 1223  12  aace0067-ddaf-e511-80ea-0050568c2fc0
# 1191  12  84ce0067-ddaf-e511-80ea-0050568c2fc0
#
#                            jurisdictionName             clerkName  \
# 1177  Town Of Springwater - Waushara County         Victoria Sage
# 1115       Town Of Bevent - Marathon County           Anne Mieska
# 1662  Village Of Howard - Multiple Counties  Christopher A Haltom
# 1223     Town Of Hazelhurst - Oneida County         Betty Cushing
# 1191     Village Of Norwalk - Monroe County         Caroline Vian
#
#                                       muncipalAddress  \
# 1177  W7033 County Road Gh, Wild Rose, Wi  54984-6615
# 1115          205825 County Road Y, Hatley, Wi  54440
# 1662     2456 Glendale Ave, Green Bay, Wi  54313-6502
# 1223          7020 Hwy 51, Hazelhurst, Wi  54531-9525
# 1191          208 S Church St, Norwalk, Wi 54648-8255
#
#                                 mailingAddress         phone1 phone2  \
# 1177  W7048 High Rd, Wild Rose, Wi  54984-9016  (920)622-3808
# 1115      207211 Moraine Rd, Hatley, Wi  54440  (715)454-7171
# 1662   Po Box 12207, Green Bay, Wi  54313-2207  (920)434-4640
# 1223     Po Box 67, Hazelhurst, Wi  54531-0067  (715)356-5800
# 1191        Po Box 230, Norwalk, Wi 54648-0230  (608)823-7760
#
#                 fax                          email  \
# 1177  (920)622-4718  clerk.springwater18@gmail.com
# 1115  (715)454-6303            amieska59@gmail.com
# 1662  (920)434-4643    CHALTOM@VILLAGEOFHOWARD.COM
# 1223  (715)358-9809           HAZELWI@FRONTIER.COM
# 1191  (608)823-7293    norwalkclerk@centurytel.net
#
#                                       notificationEmail  \
# 1177                      clerk.springwater18@gmail.com
# 1115                                amieska59@gmail.com
# 1662  CHALTOM@VILLAGEOFHOWARD.COM; aduprey@villageof...
# 1223                               HAZELWI@FRONTIER.COM
# 1191                        norwalkclerk@centurytel.net
#
#                                         key
# 1177  TOWN OF SPRINGWATER - WAUSHARA COUNTY
# 1115       TOWN OF BEVENT - MARATHON COUNTY
# 1662  VILLAGE OF HOWARD - MULTIPLE COUNTIES
# 1223     TOWN OF HAZELHURST - ONEIDA COUNTY
# 1191     VILLAGE OF NORWALK - MONROE COUNTY

# %% [markdown]
# ## Stats on which munis for which we have data

# %%
df_mail.shape
# Out:
# (635, 12)

# %%
df_muni.shape
# Out:
# (1493, 12)

# %%
all_jurisdictions = set(df_mail['jurisdictionName']) | set(df_muni['jurisdictionName'])
fetched_lens = len(all_jurisdictions)
print(fetched_lens)
# Out:
# 1600

# %% [markdown]
# ## Data agrees when there is overlap

# %%
df_merged = df_muni.merge(df_mail, on='key', how='inner')
assert((df_merged['clerkName_x'] == df_merged['clerkName_y']).all())
assert((df_merged['email_x'] == df_merged['email_y']).all())
assert((df_merged['muncipalAddress_x'] == df_merged['muncipalAddress_y']).all())

# %% [markdown]
# ## Merge: fetched data gets priority and fall back to PDF if nothing

# %%
df_fetched = pd.concat([
    df_muni.set_index('key'),
    df_mail.set_index('key'),
]).drop_duplicates()
assert(df_fetched.shape[0] == fetched_lens)
df_fetched.sample(n=5, random_state=42)
# Out:
#                                        $id  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY          12
# VILLAGE OF SOMERSET - ST. CROIX COUNTY  12
# TOWN OF FRANKFORT - PEPIN COUNTY        12
# TOWN OF HUBBARD - DODGE COUNTY          12
# VILLAGE OF ROSHOLT - PORTAGE COUNTY     12
#
#                                                               jurisdictionID  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY          c919f96c-ddaf-e511-80ea-0050568c2fc0
# VILLAGE OF SOMERSET - ST. CROIX COUNTY  3e19f96c-ddaf-e511-80ea-0050568c2fc0
# TOWN OF FRANKFORT - PEPIN COUNTY        4d18f96c-ddaf-e511-80ea-0050568c2fc0
# TOWN OF HUBBARD - DODGE COUNTY          b2810861-ddaf-e511-80ea-0050568c2fc0
# VILLAGE OF ROSHOLT - PORTAGE COUNTY     aa18f96c-ddaf-e511-80ea-0050568c2fc0
#
#                                                               jurisdictionName  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY                  Town Of Hammel - Taylor County
# VILLAGE OF SOMERSET - ST. CROIX COUNTY  Village Of Somerset - St. Croix County
# TOWN OF FRANKFORT - PEPIN COUNTY              Town Of Frankfort - Pepin County
# TOWN OF HUBBARD - DODGE COUNTY                  Town Of Hubbard - Dodge County
# VILLAGE OF ROSHOLT - PORTAGE COUNTY        Village Of Rosholt - Portage County
#
#                                               clerkName  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY             Renee Zenner
# VILLAGE OF SOMERSET - ST. CROIX COUNTY  Felicia Germain
# TOWN OF FRANKFORT - PEPIN COUNTY         Maureen Manore
# TOWN OF HUBBARD - DODGE COUNTY               Carrie Neu
# VILLAGE OF ROSHOLT - PORTAGE COUNTY     Theresa Hartvig
#
#                                                                   muncipalAddress  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY          W8792 Center Ave, Medford, Wi  54451-8528
# VILLAGE OF SOMERSET - ST. CROIX COUNTY    110 Spring St, Somerset, Wi  54025-9002
# TOWN OF FRANKFORT - PEPIN COUNTY          N3290 Byington Rd, Pepin, Wi 54759-4718
# TOWN OF HUBBARD - DODGE COUNTY               W2864  Neda Rd, Iron Ridge, Wi 53035
# VILLAGE OF ROSHOLT - PORTAGE COUNTY        101 S Main St, Rosholt, Wi  54473-9772
#
#                                                                     mailingAddress  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY          N2497 County Rd E, Medford, Wi  54451-9445
# VILLAGE OF SOMERSET - ST. CROIX COUNTY        Po Box 356, Somerset, Wi  54025-0356
# TOWN OF FRANKFORT - PEPIN COUNTY           N3290 Byington Rd, Pepin, Wi 54759-4718
# TOWN OF HUBBARD - DODGE COUNTY                W2864  Neda Rd, Iron Ridge, Wi 53035
# VILLAGE OF ROSHOLT - PORTAGE COUNTY            Po Box 245, Rosholt, Wi  54473-0245
#
#                                                phone1         phone2  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY          (715)748-9608
# VILLAGE OF SOMERSET - ST. CROIX COUNTY  (715)247-3395
# TOWN OF FRANKFORT - PEPIN COUNTY        (715)442-2685
# TOWN OF HUBBARD - DODGE COUNTY          (920)349-3223
# VILLAGE OF ROSHOLT - PORTAGE COUNTY     (715)677-4510  (715)677-4246
#
#                                                   fax  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY
# VILLAGE OF SOMERSET - ST. CROIX COUNTY  (715)247-2790
# TOWN OF FRANKFORT - PEPIN COUNTY
# TOWN OF HUBBARD - DODGE COUNTY          (920)349-3223
# VILLAGE OF ROSHOLT - PORTAGE COUNTY
#
#                                                               email  \
# key
# TOWN OF HAMMEL - TAYLOR COUNTY                  zennerfarms@tds.net
# VILLAGE OF SOMERSET - ST. CROIX COUNTY  fgermain@vil.somerset.wi.us
# TOWN OF FRANKFORT - PEPIN COUNTY          TOWNOFFRANKFORT@YAHOO.COM
# TOWN OF HUBBARD - DODGE COUNTY              townofhubbard@gmail.com
# VILLAGE OF ROSHOLT - PORTAGE COUNTY       rosholtvillage@wi-net.com
#
#                                                                       notificationEmail
# key
# TOWN OF HAMMEL - TAYLOR COUNTY                                      zennerfarms@tds.net
# VILLAGE OF SOMERSET - ST. CROIX COUNTY                      fgermain@vil.somerset.wi.us
# TOWN OF FRANKFORT - PEPIN COUNTY                              TOWNOFFRANKFORT@YAHOO.COM
# TOWN OF HUBBARD - DODGE COUNTY          kgibson@co.dodge.wi.us; townofhubbard@gmail.com
# VILLAGE OF ROSHOLT - PORTAGE COUNTY                           rosholtvillage@wi-net.com

# %%
df_noemail2 = df_noemail.set_index('key')
fix_cols = ['city_type', 'city', 'county', 'clerk', 'deputy_clerk', 'municipal_address', 'mailing_address']
for col in fix_cols:
    df_noemail2[col] = df_noemail2[col].str.title()

df_master = df_noemail2.merge(df_fetched, on='key', how='left').reset_index()
df_master['title_key'] = df_master['key'].str.title()

def merge_all_cols(df, pairs):
    return pd.DataFrame({
        first: df[first].where(df[first].notnull(), df[second])
        for first, second in pairs
    })

df_final = pd.concat([
    merge_all_cols(df_master, [
        ['muncipalAddress', 'municipal_address'],
        ['mailingAddress', 'mailing_address'],
        ['clerkName', 'clerk'],
        ['fax_y', 'fax_x'],
        ['jurisdictionName', 'title_key']
    ]),
    df_master[['email', 'notificationEmail', 'county']],
], axis=1).rename({
    'fax_y': 'fax',
    'city_type': 'cityType'
}, axis=1)

df_final['city'] = df_master['city_type'] + ' of ' + df_master['city']

df_final.sample(5, random_state=42)
# Out:
#                                     muncipalAddress  \
# 233     W1877 Us Highway 10, Granton, Wi 54436-8847
# 450   4917 S State Road 35, Superior, Wi 54880-8301
# 1240   6704 State Highway 66, Custer, Wi 54423-9641
# 1693   6355 County Road Z, West Bend, Wi 53095-9201
# 411    205 S Lincoln Ave, Beaver Dam, Wi 53916-2323
#
#                                      mailingAddress        clerkName  \
# 233              Po Box 104, Granton, Wi 54436-0104     Joye Eichten
# 450   4917 S State Road 35, Superior, Wi 54880-8301    Carolyn Jones
# 1240   6704 State Highway 66, Custer, Wi 54423-9641      Lori Printz
# 1693   6355 County Road Z, West Bend, Wi 53095-9201  Julie Ihlenfeld
# 411                                            None        Zak Bloom
#
#                 fax                       jurisdictionName  \
# 233                            Town Of Lynn - Clark County
# 450   (715)399-0181      Town Of Superior - Douglas County
# 1240  (715)592-6666        Town Of Sharon - Portage County
# 1693  (262)338-0427  Town Of West Bend - Washington County
# 411   (920)887-4662      City Of Beaver Dam - Dodge County
#
#                               email              notificationEmail  \
# 233        lynn.townclerk@gmail.com       lynn.townclerk@gmail.com
# 450   townofsuperior@centurytel.net  townofsuperior@centurytel.net
# 1240       townofsharon@outlook.com       townofsharon@outlook.com
# 1693       clerk@townofwestbend.com       clerk@townofwestbend.com
# 411                             NaN                            NaN
#
#                  county                city
# 233        Clark County        Town of Lynn
# 450      Douglas County    Town of Superior
# 1240     Portage County      Town of Sharon
# 1693  Washington County   Town of West Bend
# 411        Dodge County  City of Beaver Dam

# %%
frac1 = df_final[['email', 'notificationEmail']].notnull().any(axis=1).mean()
print(f"Have email for {frac1:%} of municipalities")

frac2 = df_final[['fax', 'email', 'notificationEmail']].notnull().any(axis=1).mean()
print(f"Have fax or email for {frac2:%} of municipalities")
# Out:
# Have email for 86.184566% of municipalities
# Have fax or email for 95.089045% of municipalities

# %%
df_output = df_final[
    ['muncipalAddress', 'mailingAddress', 'clerkName', 'jurisdictionName', 'county', 'city']
].rename({
    'muncipalAddress': 'physicalAddress',
    'mailingAddress': 'address',
    'clerkName': 'official',
    'jurisdictionName': 'locale',
}, axis=1)

def to_list(df):
    return df.apply(
        lambda x: list(set(y for y in x if pd.notnull(y) if y != '')),
        axis=1
    )

df_output['county'] = df_output['county'].replace('Multiple Counties', np.nan).str.strip()
df_output['locale'] = df_output['locale'].str.replace(' - ', ':').str.replace(' Of ', ' of ')
df_output['locale'] = df_output['locale'].str.replace('Multiple Counties', '').str.strip()
df_output['city'] = df_output['city'].str.strip()

df_output['faxes'] = to_list(df_final[['fax']])
df_output['emails'] = to_list(df_final[['email', 'notificationEmail']])
df_output.to_json('../public/wisconsin.json', orient='records')
df_output.sample(5, random_state=42)
# Out:
#                                     physicalAddress  \
# 233     W1877 Us Highway 10, Granton, Wi 54436-8847
# 450   4917 S State Road 35, Superior, Wi 54880-8301
# 1240   6704 State Highway 66, Custer, Wi 54423-9641
# 1693   6355 County Road Z, West Bend, Wi 53095-9201
# 411    205 S Lincoln Ave, Beaver Dam, Wi 53916-2323
#
#                                             address         official  \
# 233              Po Box 104, Granton, Wi 54436-0104     Joye Eichten
# 450   4917 S State Road 35, Superior, Wi 54880-8301    Carolyn Jones
# 1240   6704 State Highway 66, Custer, Wi 54423-9641      Lori Printz
# 1693   6355 County Road Z, West Bend, Wi 53095-9201  Julie Ihlenfeld
# 411                                            None        Zak Bloom
#
#                                    locale             county  \
# 233             Town of Lynn:Clark County       Clark County
# 450       Town of Superior:Douglas County     Douglas County
# 1240        Town of Sharon:Portage County     Portage County
# 1693  Town of West Bend:Washington County  Washington County
# 411       City of Beaver Dam:Dodge County       Dodge County
#
#                     city            faxes                           emails
# 233         Town of Lynn               []       [lynn.townclerk@gmail.com]
# 450     Town of Superior  [(715)399-0181]  [townofsuperior@centurytel.net]
# 1240      Town of Sharon  [(715)592-6666]       [townofsharon@outlook.com]
# 1693   Town of West Bend  [(262)338-0427]       [clerk@townofwestbend.com]
# 411   City of Beaver Dam  [(920)887-4662]                               []
